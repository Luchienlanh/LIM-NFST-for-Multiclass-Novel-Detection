# %%
# !git clone https://github.com/Luchienlanh/LIM-NFST-for-Multiclass-Novel-Detection
# Out:
# Cloning into 'LIM-NFST-for-Multiclass-Novel-Detection'...
# remote: Enumerating objects: 1824, done.
# remote: Counting objects: 100% (323/323), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 1824 (delta 308), reused 312 (delta 303), pack-reused 1501 (from 1)
# Receiving objects: 100% (1824/1824), 10.01 MiB | 10.43 MiB/s, done.
# Resolving deltas: 100% (718/718), done.

# %%
# %cd LIM-NFST-for-Multiclass-Novel-Detection
# Out:
# /content/LIM-NFST-for-Multiclass-Novel-Detection

# %%
# !python examples/lim-models-gpu.py --grid-search --dataset BoT_IoT
# Out:
# Compute: PyTorch 2.11.0+cu128, Tesla T4, float64
# Grid search: 3375 configurations per outer novel class.
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=1/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=100/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=200/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=300/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=400/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=500/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=600/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=700/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=800/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=900/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=1000/3375
# Tuning dataset=BoT_IoT outer_novel_class=0Normal configuration=1100/3375
# ...

# %%
# !python3 examples/lim-models-gpu.py --dataset BoT_IoT --novel-class 0 --seed 42
# Out:
# python3: can't open file '/content/examples/lim-models-gpu.py': [Errno 2] No such file or directory
